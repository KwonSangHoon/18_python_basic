# %%
# 위치 인수를 사용하는 함수를 만들고 호출하기
def print_numbers(a, b, c):
    print(a)
    print(b)
    print(c)

print_numbers(10, 20, 30)
# Out:
# 10
# 20
# 30

# %%
# 언패킹 사용하기
x = [10, 20, 30]
print_numbers(x) #=> ([10, 20, 30])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 # 언패킹 사용하기
#       2 x = [10, 20, 30]
# ----> 3 print_numbers(x) #=> ([10, 20, 30])
#
# TypeError: print_numbers() missing 2 required positional arguments: 'b' and 'c'

# %%
x = [10, 20, 30]
print_numbers(*x) #=> ([10, 20, 30])
# Out:
# 10
# 20
# 30

# %%
# 가변인수 함수 만들기
# def 함수이름(매개변수):
#     코드

def print_numbers(*args):
    for arg in args:
        print(arg)

# %%
print_number(10)
print("=====")
print_numbers(10, 20, 30, 40)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print_number(10)
#       2 print("=====")
#       3 print_numbers(10, 20, 30, 40)
#
# NameError: name 'print_number' is not defined

# %%
def print_numbers(*args):
    print(args)
    print(type(args))
    # for arg in args:
    #     print(arg)

print_numbers(10, 20, 30)
# Out:
# (10, 20, 30)
# <class 'tuple'>

# %%
print_numbers(*[1, 2, 3, 4, 5])
# Out:
# (1, 2, 3, 4, 5)
# <class 'tuple'>

# %%
# 키워드 인수 사용하기
def personal_info(name, age, address):
    print("이름:", name)
    print("나이:", age)
    print("주소:", address)

    personal_info("홍길동", 30, "서울시 용산구")

# %%
personal_info("홍길동", 30, "서울시 용산구")
# Out:
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
# ...
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 3, in personal_info(name, age, address)
#       2 def personal_info(name, age, address):
# ----> 3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
#
# File ~\AppData\Roaming\Python\Python314\site-packages\ipykernel\iostream.py:762, in OutStream.write(self, string)
#     759     msg = "I/O operation on closed file"
#     760     raise ValueError(msg)
# --> 762 is_child = not self._is_master_process()
#     763 # only touch the buffer in the IO thread to avoid races
#     764 with self._buffer_lock:
#
# RecursionError: maximum recursion depth exceeded

# %%
# 키워드 인수
# 함수(키워드 = 값
personal_info(name="홍길동", age=30, address="서울시 용산구")
# Out:
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[13], line 3
#       1 # 키워드 인수
#       2 # 함수(키워드 = 값
# ----> 3 personal_info(name="홍길동", age=30, address="서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
# ...
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 7, in personal_info(name, age, address)
#       3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
# ----> 7     personal_info("홍길동", 30, "서울시 용산구")
#
# Cell In[11], line 3, in personal_info(name, age, address)
#       2 def personal_info(name, age, address):
# ----> 3     print("이름:", name)
#       4     print("나이:", age)
#       5     print("주소:", address)
#       6
#
# File ~\AppData\Roaming\Python\Python314\site-packages\ipykernel\iostream.py:762, in OutStream.write(self, string)
#     759     msg = "I/O operation on closed file"
#     760     raise ValueError(msg)
# --> 762 is_child = not self._is_master_process()
#     763 # only touch the buffer in the IO thread to avoid races
#     764 with self._buffer_lock:
#
# RecursionError: maximum recursion depth exceeded

# %%
def personal_info(name, age, address):
    print("이름:", name)
    print("나이:", age)
    print("주소:", address)
personal_info(age=30, address="서울시 용산구", name="홍길동")
# Out:
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구

# %%
# 키워드 인수와 딕셔너리 언패킹 사용하기
# 함수(**딕셔너리)
def personal_info(name, age, address):
    print("이름:", name)
    print("나이:", age)
    print("주소:", address)

x = {
    "name" : "홍길동",
    "age": 30,
    "address": "서울시 용산구"
}

personal_info(**x)
# personal_info(name="홍길동", age=30, address="서울시 용산구")
# Out:
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구

# %%
# 키워드 인수를 사용하는 가변 인수 함수 만들기
# def 함수이름(**매개변수):
#     코드

def personal_info(**kwargs):
    print(kwargs)
    print(type(kwargs))
    for kw, arg in kwargs.items():
        print(kw, ": ", arg, sep="")

personal_info(name="홍길동")
# Out:
# {'name': '홍길동'}
# <class 'dict'>
# name: 홍길동

# %%
personal_info(name="홍길동", age=30, address="서울시 용산구")
# Out:
# {'name': '홍길동', 'age': 30, 'address': '서울시 용산구'}
# <class 'dict'>
# name: 홍길동
# age: 30
# address: 서울시 용산구

# %%
def personal_info(**kwargs):
    for kw, arg in kwargs.items():
        print(kw, ": ", arg, sep="")

x = {
    "name" : "홍길동",
    "age": 30,
    "address": "서울시 용산구",
    "hobby": ["축구", "농구", "게임"]
}

personal_info(**x)
# Out:
# name: 홍길동
# age: 30
# address: 서울시 용산구
# hobby: ['축구', '농구', '게임']

# %%
# 매개변수에 초깃값 지정하기
# def 함수이름(매개변수=값):
#     코드

def personal_info(name, age, address="비공개"):
    print("이름:", name)
    print("나이:", age)
    print("주소:", address)

personal_info("홍길동", 30)
# Out:
# 이름: 홍길동
# 나이: 30
# 주소: 비공개

# %%
personal_info("홍길동", 30, "서울시 이촌동")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 personal_info("홍길동", 30, "서울시 이촌동")
#
# TypeError: personal_info() takes 0 positional arguments but 3 were given

# %%
# 초깃값이 지정된 매개변수의 위치
def personal_info(name, address="비공개", age):
    print("이름:", name)
    print("나이:", age)
    print("주소:", address)
# Out:
#   Cell In[29], line 2
#     def personal_info(name, address="비공개", age):
#                                            ^
# SyntaxError: parameter without a default follows parameter with a default

# %%
# 연습문제: 가장 높은 점수를 구하는 함수 만들기

korean, english, mathematics, science = 100, 86, 81, 91

def get_max_score(*args):
    return max(args)

max_score = get_max_score (korean, english, mathematics, science)
print("높은 점수:", max_score)

max_score = get_max_score (english, science)
print("높은 점수:", max_score)
# Out:
# 높은 점수: 100
# 높은 점수: 91

# %%
# 심사문제: 가장 낮은 점수, 높은 점수와 평균 점수를 구하는 함수 만들기

korean, english, mathematics, science = map(int, input().split())

def get_min_max_score(*args):
    return min(args), max(args)


def get_average(**kwargs):
    return sum(kwargs.values()) / len(kwargs)

min_score, max_score = get_min_max_score(korean, english, mathematics, science)
average_score = get_average(korean=korean, english=english,
                            mathematics=mathematics, science=science)
print('낮은 점수: {0:.2f}, 높은 점수: {1:.2f}, 평균 점수: {2:.2f}'
      .format(min_score, max_score, average_score))

min_score, max_score = get_min_max_score(english, science)
average_score = get_average(english=english, science=science)
print('낮은 점수: {0:.2f}, 높은 점수: {1:.2f}, 평균 점수: {2:.2f}'
      .format(min_score, max_score, average_score))
# Out:
# 낮은 점수: 73.00, 높은 점수: 92.00, 평균 점수: 84.25
# 낮은 점수: 83.00, 높은 점수: 92.00, 평균 점수: 87.50

# %%
korean, english, mathematics, science = map(int, input().split())

def get_min_max_score(*args):
    return min(args), max(args)

def get_average(**kwargs):
    return sum(kwargs.values()) / len(kwargs)

min_score, max_score = get_min_max_score(korean, english, mathematics, science)
average_score = get_average(korean = korean, english = english, mathematics = mathematics, science = science)
print("낮은 점수: {0:.2f}, 높은 점수: {1:.2f}, 평균 점수: {2:.2f}".format(min_score, max_score, average_score))

min_score, max_score = get_min_max_score(english, science)
average_score = get_average(english = english, science = science)
print("낮은 점수: {0:.2f}, 높은 점수: {1:.2f}, 평균 점수: {2:.2f}".format(min_score, max_score, average_score))
# Out:
# 낮은 점수: 73.00, 높은 점수: 92.00, 평균 점수: 84.25
# 낮은 점수: 83.00, 높은 점수: 92.00, 평균 점수: 87.50

# %%
korean, english,mathamtics,science = map(int,input().split())

def get_min_max_score(*args):
    min = 100
    max = 0
    for i in args:
        if i < min:
            min = i
        if i > max:
            max = i
    return min, max

def get_average(**kargs):
   return sum(kargs.values()) / len(kargs)

min_score, max_score = get_min_max_score(korean,english,mathamtics,science)
average_score = get_average(korean=korean,english=english,mathamtics=mathamtics,science=science)
print("낮은 점수: {0:.2f}, 높은 점수: {1:.2f}, 평균 점수: {2:.2f}".format(min_score, max_score, average_score))

min_score, max_score = get_min_max_score(english,science)
average_score = get_average(english=english,science=science)
print("낮은 점수: {0:.2f}, 높은 점수: {1:.2f}, 평균 점수: {2:.2f}".format(min_score, max_score, average_score))
# Out:
# 낮은 점수: 73.00, 높은 점수: 92.00, 평균 점수: 84.25
# 낮은 점수: 83.00, 높은 점수: 92.00, 평균 점수: 87.50

# %%
count = 1

while count <= 5:
    print(count)
    count = count + 1
# Out:
# 1
# 2
# 3
# 4
# 5
