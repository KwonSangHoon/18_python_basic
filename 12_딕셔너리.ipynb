# %%
# 딕셔너리 만들기
# 딕셔너리 = {
#     키1:값1,
#     키2:값2
# }

lux = {
    "health": 490,
    "mana": 334,
    "melee": 550,
    "armor": 18.72
}
lux
# Out:
# {'health': 490, 'mana': 334, 'melee': 550, 'armor': 18.72}

# %%
# 키 이름이 중복이 되면?
lux = {
    "health": 490,
    "health": 800,
    "mana": 334,
    "melee": 550,
    "armor": 18.72
}
lux["health"]
# Out:
# 800

# %%
lux
# Out:
# {'health': 800, 'mana': 334, 'melee': 550, 'armor': 18.72}

# %%
# 딕셔너리의 키의 자료형
## 키에는 리스트와 딕셔너리는 사용할 수 없음

x = {
    100: "hundred",
    False: 0,
    3.5: [3.5, 3.5]
}
x
# Out:
# {100: 'hundred', False: 0, 3.5: [3.5, 3.5]}

# %%
x = {
    [10, 20]: 100
}
x
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 x = {
#       2     [10, 20]: 100
#       3 }
#       4 x
#
# TypeError: cannot use 'list' as a dict key (unhashable type: 'list')

# %%
# 빈 딕셔너리 만들기
딕셔너리 = {}
딕셔너리 = dict()

# int(), str(), float(), list(), typle(), bool()

x = {}
y = dict()

print(x)
print(y)
print(type(x))
print(type(y))
# Out:
# {}
# {}
# <class 'dict'>
# <class 'dict'>

# %%
# dict로 딕셔너리 만들기
lux1 = dict(
    health = 490, mana = 334, melee = 550, armor = 18.72
)

lux1
# Out:
# {'health': 490, 'mana': 334, 'melee': 550, 'armor': 18.72}

# %%
iter1 = ["health", "mana", "melee", "armor"]
iter2 = [490, 334, 550, 18.72]
dict(zip(iter1, iter2))
# Out:
# {'health': 490, 'mana': 334, 'melee': 550, 'armor': 18.72}

# %%
lux3 = dict(
    [ "health": 490, "mana": 334, "melee": 550, armor: 18.72" ]
)
lux3
# Out:
#   Cell In[19], line 2
#     [ "health": 490, "mana": 334, "melee": 550, armor: 18.72" ]
#                                                             ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
# 딕셔너리의 키에 접근하고 값 할당하기
lux = {'health': 490, 'mana': 334, 'melee': 550, 'armor': 18.72}
lux["health"]
# Out:
# 490

# %%
lux["armor"]
# Out:
# 18.72

# %%
# 딕셔너리의 키에 값 할당하기
lux = {'health': 490, 'mana': 334, 'melee': 550, 'armor': 18.72}
lux["health"] = 2037
lux["mana"] = 1184

print(lux)
# Out:
# {'health': 2037, 'mana': 1184, 'melee': 550, 'armor': 18.72}

# %%
lux["mana_regen"] = 3.28
lux
# Out:
# {'health': 2037,
#  'mana': 1184,
#  'melee': 550,
#  'armor': 18.72,
#  'mana_regen': 3.28}

# %%
lux["attack_speed"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 lux["attack_speed"]
#
# KeyError: 'attack_speed'

# %%
# 딕셔너리에 키가 있는지 확인하기
lux = {'health': 490, 'mana': 334, 'melee': 550, 'armor': 18.72}
"health" in lux
# Out:
# True

# %%
# 딕셔너리의 키 개수 구하기
lux = {'health': 490, 'mana': 334, 'melee': 550, 'armor': 18.72}
len(lux)
# Out:
# 4

# %%
# 연습문제
camille = {
    'health': 575.6,
    'health_regen': 1.7,
    'mana': 338.8,
    'mana_regen': 1.63,
    'melee': 125,
    'attack_damage': 60,
    'armor': 26,
    'magic_resistance': 32.1,
    'movement_speed': 340
}
print(camille['health'])
print(camille['movement_speed'])
# Out:
# 575.6
# 340

# %%
# 심사문제

iter1 = ["health", "health_regen", "mana", "mana_regen"]
iter2 = [575.6, 1.7, 338.8, 1.63]
dict(zip(iter1, iter2))

x = {'health': 575.6, 'health_regen': 1.7, 'mana': 338.8, 'mana_regen': 1.63}

x = input().split()

# %%
# 심사문제

iter1 = input().split()
iter2 = input().split()

# %%
dict(zip(iter1, iter2))
# Out:
# {'health': '575.6',
#  'health_regen': '1.7',
#  'mana': '338.8',
#  'mana_regen': '1.63'}
