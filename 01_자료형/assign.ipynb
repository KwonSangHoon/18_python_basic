# %%
print([1, 2, 3] + [4, 5, 6])
print(["Hi"])
print(5 in [1, 2, 3])
print("b" not in ["a", "b", "c"])
[1, 2, 3] == [4, 5, 6]
# Out:
# [1, 2, 3, 4, 5, 6]
# ['Hi']
# False
# False
# False

# %%
data = [10, 20, 30, 40, 50]
data[2] = 100
data[0:3] = [1, 2, 3]
del data[1]

data
# Out:
# [1, 3, 40, 50]
