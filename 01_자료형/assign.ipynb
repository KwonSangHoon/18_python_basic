# %%
print([1, 2, 3] + [4, 5, 6])
print(["Hi"])
print(5 in [1, 2, 3])
print("b" not in ["a", "b", "c"])
[1, 2, 3] == [4, 5, 6]
# Out:
# [1, 2, 3, 4, 5, 6]
# ['Hi']
# False
# False
# False

# %%
data = [10, 20, 30, 40, 50]
data[2] = 100
data[0:3] = [1, 2, 3]
del data[1]

data
# Out:
# [1, 3, 40, 50]

# %%
scores = [85, 92, 78, 90, 88, 76, 95, 89]

print(max(scores))
print(min(scores))
print(len(scores))
print(sum(scores))
print(sum(scores) / len(scores))
print(sorted(scores))


scores.sort()
# Out:
# 95
# 76
# 8
# 693
# 86.625
# [76, 78, 85, 88, 89, 90, 92, 95]

# %%
a = "Hello World"
list("Hello World")
b = 1
c = "1"

print(type(b))
print(type(c))

d = int(c)
print(d)
print(type(d))
# Out:
# <class 'int'>
# <class 'str'>
# 1
# <class 'int'>

# %%
a = 'a,b,c,d,e'
a.split(",")
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
b = ["Python", "is", "fun"]
" ".join(b)
# Out:
# 'Python is fun'

# %%
a = [] # a = list()

a.append(10)
print(a)
a.append(20)
print(a)
a.append(30)
print(a)
# Out:
# [10]
# [10, 20]
# [10, 20, 30]

# %%
a.insert(1, 15)
print(a)
# Out:
# [10, 15, 20, 30]

# %%
a.insert(0, 5)
print(a)
# Out:
# [5, 10, 15, 20, 30]

# %%
a.append([40, 50])
print(a)
a.extend([40, 50])
print(a)
# Out:
# [5, 10, 15, 20, 30, [40, 50], [40, 50]]
# [5, 10, 15, 20, 30, [40, 50], [40, 50], 40, 50]

# %%
items = ["a", "b", "c", "b", "d", "b", "e"]

items.remove("b")
print(items)
# Out:
# ['a', 'c', 'b', 'd', 'b', 'e']

# %%
items.pop()
print(items)
# Out:
# ['a', 'c', 'b', 'd', 'b']

# %%
items.pop(0)
print(items)
# Out:
# ['c', 'b', 'd', 'b']

# %%
items.clear()
print(items)
# Out:
# []

# %%
data = [3, 1, 4, 1, 5, 9, 2, 6, 5, 3, 5]

data.index(5)
# Out:
# 4

# %%
print(data.count(5))
print(data.count(1))
# Out:
# 3
# 2

# %%
numbers = [64, 34, 25, 12, 22, 11, 90]
words = ["banana", "Apple", "cherry", "date"]

numbers.sort()
print(numbers)

numbers.sort(reverse=True)
print(numbers)
# Out:
# [11, 12, 22, 25, 34, 64, 90]
# [90, 64, 34, 25, 22, 12, 11]

# %%
words.sort()
print(words)

words.reverse()
print(words)
# Out:
# ['Apple', 'banana', 'cherry', 'date']
# ['date', 'cherry', 'banana', 'Apple']

# %%
a = (1, 2, 3, 4, 5)
a = ("red", "green", "blue")
a = (1, )
a = ()
a = tuple()
a = 1,
a =

# %%
dict["전공"] = "컴퓨터 학부"
print(dict)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 dict["전공"] = "컴퓨터 학부"
#       2 print(dict)
#
# TypeError: 'type' object does not support item assignment

# %%
dict["취미"].append("운동")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 dict["취미"].append("운동")
#
# AttributeError: type object 'dict' has no attribute 'append'

# %%
dict["취미"].append("운동")
print(dict["취미"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 dict["취미"].append("운동")
#       2 print(dict["취미"])
#
# AttributeError: type object 'dict' has no attribute 'append'

# %%
fruits = {
    'apple': 1000,
    'banana': 1500,
    'orange': 2000,
    'grape': 3000
}

fruits.keys()
fruits.values()
# Out:
# dict_values([1000, 1500, 2000, 3000])

# %%
fruits["banana"]
# Out:
# 1500

# %%
학생1: 이름=김민수, 국어=85, 영어=90, 수학=78
학생2: 이름=이영희, 국어=92, 영어=88, 수학=95
학생3: 이름=박철수, 국어=78, 영어=85, 수학=82

학생1 = student["학생1"]
총점1 = 학생1["국어"] + 학생1["영어"] + 학생1["수학"]
평균1 = 총점1 / 3
# Out:
#   Cell In[47], line 1
#     학생1: 이름=김민수, 국어=85, 영어=90, 수학=78
#                    ^
# SyntaxError: invalid syntax

# %%
text = "python is great python is fun python is powerful"

a = text.split()

a.count("python")
# Out:
# 3

# %%
school = {
    '1반': {
        '김철수': {'국어': 85, '영어': 90, '수학': 78},
        '이영희': {'국어': 92, '영어': 88, '수학': 95}
    },
    '2반': {
        '박민수': {'국어': 88, '영어': 85, '수학': 90},
        '최지영': {'국어': 95, '영어': 92, '수학': 88}
    }
}

school["1반"]["김철수"]["수학"]
# Out:
# 78

# %%
sum(list(school["2반"]["박민수"].valuses())) / 3
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 sum(list(school["2반"]["박민수"].valuses())) / 3
#
# AttributeError: 'dict' object has no attribute 'valuses'

# %%
박민수 = school["2반"]["박민수"]
박민수["국어"] + 박민수["영어"] + 박민수["수학"]
# Out:
# 263

# %%
school = [
        {'이름': '김철수', '국어': 85, '영어': 90, '수학': 78},
        {'이름': '이영희', '국어': 92, '영어': 88, '수학': 95}, 
        {'이름': '박민수', '국어': 88, '영어': 85, '수학': 90},
        {'이름': '최지영', '국어': 95, '영어': 92, '수학': 88}
]
type(shcool)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 7
#       3         {'이름': '이영희', '국어': 92, '영어': 88, '수학': 95},
#       4         {'이름': '박민수', '국어': 88, '영어': 85, '수학': 90},
#       5         {'이름': '최지영', '국어': 95, '영어': 92, '수학': 88}
#       6 ]
# ----> 7 type(shcool)
#
# NameError: name 'shcool' is not defined

# %%
print(type(school[3]))
school[3]["국어"]
# Out:
# <class 'dict'>
# 95

# %%
이영희 = school["이영희"]
박민수["국어"] + 박민수["영어"] + 박민수["수학"] / 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 이영희 = school["이영희"]
#       2 박민수["국어"] + 박민수["영어"] + 박민수["수학"] / 3
#
# TypeError: list indices must be integers or slices, not str

# %%
a = [1, 2, 3, 2, 1, 3, 4]
s2 = set(a)
s2
list(s2)
# Out:
# [1, 2, 3, 4]

# %%
a = {'김철수', '이영희', '박민수', '최지영', '홍길동'}
b = {'박민수', '최지영', '정수민', '강호동', '이영희'}

# %%
a & b
a.intersection(b)
# Out:
# {'박민수', '이영희', '최지영'}

# %%
fruits . add(grape)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 fruits . add(grape)
#
# AttributeError: 'dict' object has no attribute 'add'
